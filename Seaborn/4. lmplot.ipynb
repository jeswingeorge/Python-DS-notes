# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# # [seaborn lmplot](https://seaborn.pydata.org/generated/seaborn.lmplot.html)
#
# Plot data and regression model fits across a FacetGrid.
#
# This function combines `regplot()` and [FacetGrid](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html#seaborn.FacetGrid). It is intended as a convenient interface to fit regression models across conditional subsets of a dataset.
#
# When thinking about how to assign variables to different facets, a general rule is that it makes sense to use `hue` for the most important comparison, followed by `col` and `row`. However, always think about your particular dataset and the goals of the visualization you are creating.
#
# The `regplot()` and `lmplot()` functions are closely related, but the former is an axes-level function while the latter is a figure-level function that combines `regplot()` and `FacetGrid`.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Plot a simple linear relationship between two variables:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip');

# %% [markdown]
# ### Condition on a third variable and plot the levels in different colors:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker');

# %% [markdown]
# ### Condition on a third variable and plot the levels in different colors and markers:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker', markers = ['o', '+']);

# %% [markdown]
# ### Use a different color palette for the above plot:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker', palette = "Set1");

# %% [markdown]
# ### Map `hue` levels to colors with a dictionary:
# __Reference:__ [matplotlib.colors](https://matplotlib.org/2.0.2/api/colors_api.html#module-matplotlib.colors)

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker', palette=dict(Yes='g', No='m'));

# %% [markdown]
# ### Plot the levels of the third variable across different columns:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', col = 'time');

# %% [markdown]
# ### Change the height and aspect ratio of the facets:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', col = 'day');

# %% [markdown]
# To change the height, width and color of the graphs use the following parameters: `height`, `aspect` and `hue`.
# - __Size/height__ will change the height, while maintaining the aspect ratio (so it will also also get wider if only size is changed.)
#
# - __Aspect__ will change the width while keeping the height constant.

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', col = 'day', hue = 'day', height=10, aspect=0.8);

# %% [markdown]
# ### Wrap the levels of the column variable into multiple rows:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', col = 'day', hue = 'day', height=7, aspect=0.8, col_wrap=2);

# %% [markdown]
# ### Condition on two variables to make a full grid:

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', row = 'sex', col = 'time');
