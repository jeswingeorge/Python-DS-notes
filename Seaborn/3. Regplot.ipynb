# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# # [Seaborn regplot](https://seaborn.pydata.org/generated/seaborn.regplot.html)
#
# Plot data and a linear regression model fit.
#
# #### difference between regplot and lmplot in seaborn
#
# `regplot()` performs a simple linear regression model fit and plot. `lmplot()` combines `regplot()` and `FacetGrid`.
#
# The `FacetGrid` class helps in visualizing the distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.
#
# `lmplot()` is more computationally intensive and is intended as a convenient interface to fit regression models across conditional subsets of a dataset.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Plot regplot using two numerical variables from a dataframe

# %%
plt.figure(figsize=(13,7));
sns.regplot(data = tips, x = "total_bill", y = 'tip');

# %% [markdown]
# ### Use a 68% confidence interval, which corresponds with the standard error of the estimate:

# %%
plt.figure(figsize=(13,7));
sns.regplot(data = tips, x = "total_bill", y = 'tip', ci = 68);

# %% [markdown]
# ### Plot with a discrete `x` variable and add some `jitter`:

# %%
plt.figure(figsize=(13,7));
sns.regplot(x="size", y="total_bill", data=tips, x_jitter=.1);

# %% [markdown]
# ### Plot with a discrete `x` variable showing means and confidence intervals for unique values using `x_estimator `:

# %%
plt.figure(figsize=(12,7));
sns.regplot(x="size", y="total_bill", data=tips, x_estimator=np.mean);

# %% [markdown]
# ### Plot with two variables defined as pandas Series; use a different marker:
#
# ##### Reference:
# - [numpy random randint](https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.random.randint.html):
# Return random integers from low (inclusive) to high (exclusive). Return random integers from the “discrete uniform” distribution of the specified dtype in the “half-open” interval

# %%
x = pd.Series(np.random.randint(low = 1, high = 11, size = 100))
y = pd.Series(np.random.randint(low = 1, high = 11, size = 100))
plt.figure(figsize=(13,7));
sns.regplot(x = x, y = y, marker = '*');
